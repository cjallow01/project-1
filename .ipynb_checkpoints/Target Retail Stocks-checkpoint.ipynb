# %%
import yfinance as yf

# %%
Target = yf.Ticker("TGT")

# %%
print(Target)
# Out:
# yfinance.Ticker object <TGT>

# %%
Target.info
# Out:
# {'zip': '55403',
#  'sector': 'Consumer Defensive',
#  'fullTimeEmployees': 450000,
#  'longBusinessSummary': 'Target Corporation operates as a general merchandise retailer in the United States. The company offers food assortments, including perishables, dry grocery, dairy, and frozen items; apparel, accessories, home décor products, electronics, toys, seasonal offerings, food, and other merchandise; and beauty and household essentials. It also provides in-store amenities, such as Target Café, Target Optical, Starbucks, and other food service offerings. The company sells its products through its stores; and digital channels, including Target.com. As of March 09, 2022, the company operated approximately 2,000 stores. Target Corporation was incorporated in 1902 and is headquartered in Minneapolis, Minnesota.',
#  'city': 'Minneapolis',
#  'phone': '612 304 6073',
#  'state': 'MN',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://corporate.target.com',
#  'maxAge': 1,
#  'address1': '1000 Nicollet Mall',
#  'industry': 'Discount Stores',
#  'ebitdaMargins': 0.07911,
#  'profitMargins': 0.03916,
#  'grossMargins': 0.26225,
#  'operatingCashflow': 5155999744,
#  'revenueGrowth': 0.035,
#  'operatingMargins': 0.05434,
#  'ebitda': 8531999744,
#  'targetLowPrice': 161,
#  'recommendationKey': 'buy',
#  'grossProfits': 31042000000,
#  'freeCashflow': -365500000,
#  'targetMedianPrice': 190,
#  'currentPrice': 152.99,
#  'earningsGrowth': -0.893,
#  'currentRatio': 0.822,
#  'returnOnAssets': 0.070539996,
#  'numberOfAnalystOpinions': 29,
#  'targetMeanPrice': 192.24,
#  'debtToEquity': 169.288,
#  'returnOnEquity': 0.33192003,
#  'targetHighPrice': 244,
#  'totalCash': 1151000064,
#  'totalDebt': 17930999808,
#  'totalRevenue': 107855003648,
#  'totalCashPerShare': 2.501,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 228.458,
#  'quickRatio': 0.051,
#  'recommendationMean': 2.1,
#  'exchange': 'NYQ',
#  'shortName': 'Target Corporation',
#  'longName': 'Target Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'TGT',
#  'messageBoardId': 'finmb_174438',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 0.845,
#  'beta3Year': None,
#  'enterpriseToEbitda': 10.685,
#  '52WeekChange': -0.3686965,
#  'morningStarRiskRating': None,
#  'forwardEps': 11.91,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 460263008,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 23.014,
#  'sharesShort': 9386966,
#  'sharesPercentSharesOut': 0.020399999,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1643414400,
#  'heldPercentInstitutions': 0.7974,
#  'netIncomeToCommon': 4224000000,
#  'trailingEps': 8.93,
#  'lastDividendValue': 1.08,
#  'SandP52WeekChange': -0.17616767,
#  'priceToBook': 6.647693,
#  'heldPercentInsiders': 0.00204,
#  'nextFiscalYearEnd': 1706486400,
#  'yield': None,
#  'mostRecentQuarter': 1659225600,
#  'shortRatio': 2.88,
#  'sharesShortPreviousMonthDate': 1663200000,
#  'floatShares': 459033729,
#  'beta': 1.0214,
#  'enterpriseValue': 91167645696,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 964051200,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1660608000,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.899,
#  'priceToSalesTrailing12Months': 0.65287316,
#  'dateShortInterest': 1665705600,
#  'pegRatio': 1.03,
#  'ytdReturn': None,
#  'forwardPE': 12.845509,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.020399999,
#  'sharesShortPriorMonth': 9261999,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 161.62,
#  'regularMarketOpen': 161.08,
#  'twoHundredDayAverage': 182.14595,
#  'trailingAnnualDividendYield': 0.022274472,
#  'payoutRatio': 0.4077,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 161.59,
#  'navPrice': None,
#  'averageDailyVolume10Day': 3110240,
#  'regularMarketPreviousClose': 161.62,
#  'fiftyDayAverage': 159.5344,
#  'trailingAnnualDividendRate': 3.6,
#  'open': 161.08,
#  'toCurrency': None,
#  'averageVolume10days': 3110240,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 4.32,
#  'exDividendDate': 1668470400,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 152.5,
#  'currency': 'USD',
#  'trailingPE': 17.13214,
#  'regularMarketVolume': 4018378,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 70415638528,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 3691109,
#  'dayLow': 152.5,
#  'ask': 153.48,
#  'askSize': 800,
#  'volume': 4018378,
#  'fiftyTwoWeekHigh': 268.98,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2.35,
#  'fiftyTwoWeekLow': 137.16,
#  'bid': 152.85,
#  'tradeable': False,
#  'dividendYield': 0.027,
#  'bidSize': 1100,
#  'dayHigh': 161.59,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 152.99,
#  'preMarketPrice': 161.95,
#  'logo_url': 'https://logo.clearbit.com/corporate.target.com'}

# %%
df = yf.download(tickers,  start = "2021-02-01" , end = "2021-02-04")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df = yf.download(tickers,  start = "2021-02-01" , end = "2021-02-04")
#
# NameError: name 'tickers' is not defined

# %%
Target.history(period="max")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1973-02-21 00:00:00-05:00    0.000000    0.208598    0.203631    0.203631
# 1973-02-22 00:00:00-05:00    0.000000    0.203631    0.193698    0.194940
# 1973-02-23 00:00:00-05:00    0.000000    0.196181    0.192456    0.192456
# 1973-02-26 00:00:00-05:00    0.000000    0.192456    0.188731    0.188731
# 1973-02-27 00:00:00-05:00    0.000000    0.187490    0.183765    0.186248
# ...                               ...         ...         ...         ...
# 2022-11-03 00:00:00-04:00  157.979996  160.789993  157.750000  159.800003
# 2022-11-04 00:00:00-04:00  162.410004  162.750000  156.259995  159.630005
# 2022-11-07 00:00:00-05:00  161.240005  161.410004  158.000000  159.869995
# 2022-11-08 00:00:00-05:00  161.320007  164.660004  159.809998  161.619995
# 2022-11-09 00:00:00-05:00  161.080002  161.589996  152.500000  152.990005
#
#                             Volume  Dividends  Stock Splits
# Date
# 1973-02-21 00:00:00-05:00   523200        0.0           0.0
# 1973-02-22 00:00:00-05:00   360000        0.0           0.0
# 1973-02-23 00:00:00-05:00   206400        0.0           0.0
# 1973-02-26 00:00:00-05:00   235200        0.0           0.0
# 1973-02-27 00:00:00-05:00   619200        0.0           0.0
# ...                            ...        ...           ...
# 2022-11-03 00:00:00-04:00  3041600        0.0           0.0
# 2022-11-04 00:00:00-04:00  2653000        0.0           0.0
# 2022-11-07 00:00:00-05:00  2424100        0.0           0.0
# 2022-11-08 00:00:00-05:00  3284600        0.0           0.0
# 2022-11-09 00:00:00-05:00  4018378        0.0           0.0
#
# [12542 rows x 7 columns]
