# %%
#Team-7 Project-1
# Proposal - We are working on data to analyze the stock market for some retails company's to check the performance of their stocks during the covid-19 pandemic (Pre-Covid, Before Vaccine and After Vaccine release).

#Questions:
#1. How did the stocks performs pre covid? (Jan-2019 to Dec-2019)
#2. How did the stocks performs during the pandemic before the vaccine release? Jan-2020 to Nov-2021
#3. How did the stocks perform during the pandemic after the vaccine release? Dec-2020 to Dec-2021

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json 
import time
import yfinance as yf
import datetime as dt

# %%
#1. How did the stocks performs Pre-Covid from Jan-2019 to Dec-2019)

# %%
#Lowes data
import yfinance as yf

lowes=yf.Ticker("LOW")

print(lowes)

# get stock info
lowes.info

# get historical market data, here max is 5 years.
lowes.history(period="max")
# Out:
# yfinance.Ticker object <LOW>
#                                  Open        High         Low       Close  \
# Date
# 1980-03-17 00:00:00-05:00    0.000000    0.292091    0.284909    0.284909
# 1980-03-18 00:00:00-05:00    0.000000    0.287303    0.277726    0.277726
# 1980-03-19 00:00:00-05:00    0.000000    0.280120    0.275332    0.277726
# 1980-03-20 00:00:00-05:00    0.000000    0.282515    0.277726    0.277726
# 1980-03-21 00:00:00-05:00    0.000000    0.280120    0.272938    0.272938
# ...                               ...         ...         ...         ...
# 2022-11-07 00:00:00-05:00  183.570007  187.800003  181.039993  186.559998
# 2022-11-08 00:00:00-05:00  188.059998  190.009995  185.779999  188.360001
# 2022-11-09 00:00:00-05:00  187.309998  191.270004  186.309998  186.630005
# 2022-11-10 00:00:00-05:00  195.309998  204.740005  195.300003  204.320007
# 2022-11-11 00:00:00-05:00  205.089996  211.259995  204.509995  209.020004
#
#                             Volume  Dividends  Stock Splits
# Date
# 1980-03-17 00:00:00-05:00   217600        0.0           0.0
# 1980-03-18 00:00:00-05:00   272000        0.0           0.0
# 1980-03-19 00:00:00-05:00   777600        0.0           0.0
# 1980-03-20 00:00:00-05:00  2105600        0.0           0.0
# 1980-03-21 00:00:00-05:00   348800        0.0           0.0
# ...                            ...        ...           ...
# 2022-11-07 00:00:00-05:00  2715300        0.0           0.0
# 2022-11-08 00:00:00-05:00  2880800        0.0           0.0
# 2022-11-09 00:00:00-05:00  3007200        0.0           0.0
# 2022-11-10 00:00:00-05:00  4837200        0.0           0.0
# 2022-11-11 00:00:00-05:00  4272100        0.0           0.0
#
# [10758 rows x 7 columns]

# %%
# Convert the lowes data into a Pandas DataFrame
lowes_data_df = pd.DataFrame(lowes.history(period="max"))

# Show Record Count
lowes_data_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-03-17 00:00:00-05:00    0.000000    0.292091    0.284909    0.284909
# 1980-03-18 00:00:00-05:00    0.000000    0.287303    0.277726    0.277726
# 1980-03-19 00:00:00-05:00    0.000000    0.280120    0.275332    0.277726
# 1980-03-20 00:00:00-05:00    0.000000    0.282515    0.277726    0.277726
# 1980-03-21 00:00:00-05:00    0.000000    0.280120    0.272938    0.272938
# ...                               ...         ...         ...         ...
# 2022-11-07 00:00:00-05:00  183.570007  187.800003  181.039993  186.559998
# 2022-11-08 00:00:00-05:00  188.059998  190.009995  185.779999  188.360001
# 2022-11-09 00:00:00-05:00  187.309998  191.270004  186.309998  186.630005
# 2022-11-10 00:00:00-05:00  195.309998  204.740005  195.300003  204.320007
# 2022-11-11 00:00:00-05:00  205.089996  211.259995  204.509995  209.020004
#
#                             Volume  Dividends  Stock Splits
# Date
# 1980-03-17 00:00:00-05:00   217600        0.0           0.0
# 1980-03-18 00:00:00-05:00   272000        0.0           0.0
# 1980-03-19 00:00:00-05:00   777600        0.0           0.0
# 1980-03-20 00:00:00-05:00  2105600        0.0           0.0
# 1980-03-21 00:00:00-05:00   348800        0.0           0.0
# ...                            ...        ...           ...
# 2022-11-07 00:00:00-05:00  2715300        0.0           0.0
# 2022-11-08 00:00:00-05:00  2880800        0.0           0.0
# 2022-11-09 00:00:00-05:00  3007200        0.0           0.0
# 2022-11-10 00:00:00-05:00  4837200        0.0           0.0
# 2022-11-11 00:00:00-05:00  4272100        0.0           0.0
#
# [10758 rows x 7 columns]

# %%
#Pulling Lowes data 
lowes_data_df.reset_index(inplace=True)
lowes_data_df['index'] = lowes_data_df.index
lowes_data_df['Date'] = pd.to_datetime(lowes_data_df['Date'], format='%Y-%m-%d')
lowes_data_df = lowes_data_df[["Date","Close"]]
lowes_data_df
# Out:
#                            Date       Close
# 0     1980-03-17 00:00:00-05:00    0.284909
# 1     1980-03-18 00:00:00-05:00    0.277726
# 2     1980-03-19 00:00:00-05:00    0.277726
# 3     1980-03-20 00:00:00-05:00    0.277726
# 4     1980-03-21 00:00:00-05:00    0.272938
# ...                         ...         ...
# 10753 2022-11-07 00:00:00-05:00  186.559998
# 10754 2022-11-08 00:00:00-05:00  188.360001
# 10755 2022-11-09 00:00:00-05:00  186.630005
# 10756 2022-11-10 00:00:00-05:00  204.320007
# 10757 2022-11-11 00:00:00-05:00  209.020004
#
# [10758 rows x 2 columns]

# %%
# Export the City_Data into a csv
lowes_data_df.to_csv("lowes.csv")

# %%
lowes_data_df.dtypes
# Out:
# Date     datetime64[ns, America/New_York]
# Close                             float64
# dtype: object

# %%
lowes_pre_covid_df = lowes_data_df.loc[((lowes_data_df['Date'].dt.year == 2019))]
lowes_pre_covid_df.sort_values(by=['Date'])
# Out:
#                            Date       Close
# 9783  2019-01-02 00:00:00-05:00   86.047882
# 9784  2019-01-03 00:00:00-05:00   85.022064
# 9785  2019-01-04 00:00:00-05:00   87.539986
# 9786  2019-01-07 00:00:00-05:00   89.199974
# 9787  2019-01-08 00:00:00-05:00   91.046455
# ...                         ...         ...
# 10030 2019-12-24 00:00:00-05:00  113.905365
# 10031 2019-12-26 00:00:00-05:00  113.867340
# 10032 2019-12-27 00:00:00-05:00  114.342873
# 10033 2019-12-30 00:00:00-05:00  114.171669
# 10034 2019-12-31 00:00:00-05:00  113.895866
#
# [252 rows x 2 columns]

# %%
#Create a dataframe for Target pre-covid stock data (Jan 2019 - Dec 2019) By Month
monthly_close_pre_covid_df = pd.DataFrame(lowes_pre_covid_df.groupby(lowes_pre_covid_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_pre_covid_df['Store'] = 'Lowes'
monthly_close_pre_covid_df['Timeframe'] = 'Pre-Covid'

monthly_close_pre_covid_df
# Out:
#     Month       Close  Store  Timeframe
# 0       1   88.150026  Lowes  Pre-Covid
# 1       2   95.365171  Lowes  Pre-Covid
# 2       3   97.004632  Lowes  Pre-Covid
# 3       4  106.829589  Lowes  Pre-Covid
# 4       5   97.962674  Lowes  Pre-Covid
# 5       6   92.448916  Lowes  Pre-Covid
# 6       7   97.950395  Lowes  Pre-Covid
# 7       8   95.733546  Lowes  Pre-Covid
# 8       9  106.231023  Lowes  Pre-Covid
# 9      10  104.403743  Lowes  Pre-Covid
# 10     11  109.404132  Lowes  Pre-Covid
# 11     12  112.510076  Lowes  Pre-Covid

# %%
#Lowes Pre-Covid graph Jan 2019 - Dec 2019
x = monthly_close_pre_covid_df['Month']
y = monthly_close_pre_covid_df['Close']

plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Lowes (Pre-Covid) Jan-2019 to Dec-2019");

# %%
# Walmart Pre Covid(Jan 2019-Dec 2019)
import yfinance as yf

Walmart=yf.Ticker("WMT")

print(Walmart)

# get stock info
Walmart.info

# get historical market data, here max is 5 years.
Walmart.history(period="max")
# Out:
# yfinance.Ticker object <WMT>
#                                  Open        High         Low       Close  \
# Date
# 1972-08-25 00:00:00-04:00    0.035473    0.036155    0.035473    0.036018
# 1972-08-28 00:00:00-04:00    0.036018    0.036291    0.035882    0.035882
# 1972-08-29 00:00:00-04:00    0.035746    0.035746    0.035473    0.035473
# 1972-08-30 00:00:00-04:00    0.035473    0.035473    0.035200    0.035473
# 1972-08-31 00:00:00-04:00    0.035200    0.035200    0.034927    0.034927
# ...                               ...         ...         ...         ...
# 2022-11-07 00:00:00-05:00  141.259995  142.970001  141.259995  142.449997
# 2022-11-08 00:00:00-05:00  142.580002  144.070007  141.509995  142.789993
# 2022-11-09 00:00:00-05:00  142.759995  143.160004  139.210007  139.470001
# 2022-11-10 00:00:00-05:00  142.509995  142.690002  140.500000  142.360001
# 2022-11-11 00:00:00-05:00  142.669998  143.119995  139.990005  142.580002
#
#                             Volume  Dividends  Stock Splits
# Date
# 1972-08-25 00:00:00-04:00  2508800        0.0           0.0
# 1972-08-28 00:00:00-04:00   972800        0.0           0.0
# 1972-08-29 00:00:00-04:00  1945600        0.0           0.0
# 1972-08-30 00:00:00-04:00   409600        0.0           0.0
# 1972-08-31 00:00:00-04:00   870400        0.0           0.0
# ...                            ...        ...           ...
# 2022-11-07 00:00:00-05:00  3788000        0.0           0.0
# 2022-11-08 00:00:00-05:00  5022800        0.0           0.0
# 2022-11-09 00:00:00-05:00  5310700        0.0           0.0
# 2022-11-10 00:00:00-05:00  6770200        0.0           0.0
# 2022-11-11 00:00:00-05:00  6419700        0.0           0.0
#
# [12664 rows x 7 columns]

# %%
Walmart_data_df = pd.DataFrame(Walmart.history(period="max"))
Walmart_data_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1972-08-25 00:00:00-04:00    0.035473    0.036155    0.035473    0.036018
# 1972-08-28 00:00:00-04:00    0.036018    0.036291    0.035882    0.035882
# 1972-08-29 00:00:00-04:00    0.035746    0.035746    0.035473    0.035473
# 1972-08-30 00:00:00-04:00    0.035473    0.035473    0.035200    0.035473
# 1972-08-31 00:00:00-04:00    0.035200    0.035200    0.034927    0.034927
# ...                               ...         ...         ...         ...
# 2022-11-07 00:00:00-05:00  141.259995  142.970001  141.259995  142.449997
# 2022-11-08 00:00:00-05:00  142.580002  144.070007  141.509995  142.789993
# 2022-11-09 00:00:00-05:00  142.759995  143.160004  139.210007  139.470001
# 2022-11-10 00:00:00-05:00  142.509995  142.690002  140.500000  142.360001
# 2022-11-11 00:00:00-05:00  142.669998  143.119995  139.990005  142.580002
#
#                             Volume  Dividends  Stock Splits
# Date
# 1972-08-25 00:00:00-04:00  2508800        0.0           0.0
# 1972-08-28 00:00:00-04:00   972800        0.0           0.0
# 1972-08-29 00:00:00-04:00  1945600        0.0           0.0
# 1972-08-30 00:00:00-04:00   409600        0.0           0.0
# 1972-08-31 00:00:00-04:00   870400        0.0           0.0
# ...                            ...        ...           ...
# 2022-11-07 00:00:00-05:00  3788000        0.0           0.0
# 2022-11-08 00:00:00-05:00  5022800        0.0           0.0
# 2022-11-09 00:00:00-05:00  5310700        0.0           0.0
# 2022-11-10 00:00:00-05:00  6770200        0.0           0.0
# 2022-11-11 00:00:00-05:00  6419700        0.0           0.0
#
# [12664 rows x 7 columns]

# %%
Walmart_data_df.to_csv("Walmart.csv")

# %%
Walmart_data_df.reset_index(inplace=True)
Walmart_data_df['index'] = Walmart_data_df.index
Walmart_data_df['Date'] = pd.to_datetime(Walmart_data_df['Date'], format='%Y-%m-%d')
Walmart_data_df = Walmart_data_df[["Date","Close"]]
Walmart_data_df
# Out:
#                            Date       Close
# 0     1972-08-25 00:00:00-04:00    0.036018
# 1     1972-08-28 00:00:00-04:00    0.035882
# 2     1972-08-29 00:00:00-04:00    0.035473
# 3     1972-08-30 00:00:00-04:00    0.035473
# 4     1972-08-31 00:00:00-04:00    0.034927
# ...                         ...         ...
# 12659 2022-11-07 00:00:00-05:00  142.449997
# 12660 2022-11-08 00:00:00-05:00  142.789993
# 12661 2022-11-09 00:00:00-05:00  139.470001
# 12662 2022-11-10 00:00:00-05:00  142.360001
# 12663 2022-11-11 00:00:00-05:00  142.580002
#
# [12664 rows x 2 columns]

# %%
Walmart_pre_covid_df = Walmart_data_df.loc[((Walmart_data_df['Date'].dt.year == 2019))]
Walmart_pre_covid_df.sort_values(by=['Date'])
# Out:
#                            Date       Close
# 11689 2019-01-02 00:00:00-05:00   87.534355
# 11690 2019-01-03 00:00:00-05:00   87.084213
# 11691 2019-01-04 00:00:00-05:00   87.628136
# 11692 2019-01-07 00:00:00-05:00   88.659706
# 11693 2019-01-08 00:00:00-05:00   89.278671
# ...                         ...         ...
# 11936 2019-12-24 00:00:00-05:00  114.346458
# 11937 2019-12-26 00:00:00-05:00  114.356003
# 11938 2019-12-27 00:00:00-05:00  114.422966
# 11939 2019-12-30 00:00:00-05:00  114.241188
# 11940 2019-12-31 00:00:00-05:00  113.705376
#
# [252 rows x 2 columns]

# %%
#Create a dataframe for Walmart pre-covid stock data (Jan 2019 - Dec 2019) By Month
monthly_close_pre_covid_df = pd.DataFrame(Walmart_pre_covid_df.groupby(Walmart_pre_covid_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_pre_covid_df['Store'] = 'Walmart'
monthly_close_pre_covid_df['Timeframe'] = 'Pre-Covid'

monthly_close_pre_covid_df
# Out:
#     Month       Close    Store  Timeframe
# 0       1   89.849827  Walmart  Pre-Covid
# 1       2   91.693745  Walmart  Pre-Covid
# 2       3   92.446725  Walmart  Pre-Covid
# 3       4   95.132824  Walmart  Pre-Covid
# 4       5   95.935223  Walmart  Pre-Covid
# 5       6  102.591158  Walmart  Pre-Covid
# 6       7  106.997392  Walmart  Pre-Covid
# 7       8  104.942946  Walmart  Pre-Covid
# 8       9  111.288795  Walmart  Pre-Covid
# 9      10  112.963654  Walmart  Pre-Covid
# 10     11  113.651522  Walmart  Pre-Covid
# 11     12  114.313066  Walmart  Pre-Covid

# %%
x = monthly_close_pre_covid_df['Month']
y = monthly_close_pre_covid_df['Close']

plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Walmart (Pre-Covid) Jan-2019 to Dec-2019");

# %%
# Target Pre Covid(Jan 2019-Dec 2019)
import yfinance as yf

Target=yf.Ticker("TGT")

print(Target)

# get stock info
Target.info

# get historical market data, here max is 5 years.
Target.history(period="max")
# Out:
# yfinance.Ticker object <TGT>
#                                  Open        High         Low       Close  \
# Date
# 1973-02-21 00:00:00-05:00    0.000000    0.208598    0.203631    0.203631
# 1973-02-22 00:00:00-05:00    0.000000    0.203631    0.193698    0.194940
# 1973-02-23 00:00:00-05:00    0.000000    0.196181    0.192456    0.192456
# 1973-02-26 00:00:00-05:00    0.000000    0.192456    0.188731    0.188731
# 1973-02-27 00:00:00-05:00    0.000000    0.187490    0.183765    0.186248
# ...                               ...         ...         ...         ...
# 2022-11-07 00:00:00-05:00  161.240005  161.410004  158.000000  159.869995
# 2022-11-08 00:00:00-05:00  161.320007  164.660004  159.809998  161.619995
# 2022-11-09 00:00:00-05:00  161.080002  161.589996  152.500000  152.990005
# 2022-11-10 00:00:00-05:00  158.940002  164.550003  158.389999  164.380005
# 2022-11-11 00:00:00-05:00  165.119995  174.830002  164.949997  173.320007
#
#                             Volume  Dividends  Stock Splits
# Date
# 1973-02-21 00:00:00-05:00   523200        0.0           0.0
# 1973-02-22 00:00:00-05:00   360000        0.0           0.0
# 1973-02-23 00:00:00-05:00   206400        0.0           0.0
# 1973-02-26 00:00:00-05:00   235200        0.0           0.0
# 1973-02-27 00:00:00-05:00   619200        0.0           0.0
# ...                            ...        ...           ...
# 2022-11-07 00:00:00-05:00  2424100        0.0           0.0
# 2022-11-08 00:00:00-05:00  3284600        0.0           0.0
# 2022-11-09 00:00:00-05:00  4018400        0.0           0.0
# 2022-11-10 00:00:00-05:00  4962900        0.0           0.0
# 2022-11-11 00:00:00-05:00  5826900        0.0           0.0
#
# [12544 rows x 7 columns]

# %%
Target_data_df = pd.DataFrame(Target.history(period="max"))
Target_data_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1973-02-21 00:00:00-05:00    0.000000    0.208598    0.203631    0.203631
# 1973-02-22 00:00:00-05:00    0.000000    0.203631    0.193698    0.194940
# 1973-02-23 00:00:00-05:00    0.000000    0.196181    0.192456    0.192456
# 1973-02-26 00:00:00-05:00    0.000000    0.192456    0.188731    0.188731
# 1973-02-27 00:00:00-05:00    0.000000    0.187490    0.183765    0.186248
# ...                               ...         ...         ...         ...
# 2022-11-07 00:00:00-05:00  161.240005  161.410004  158.000000  159.869995
# 2022-11-08 00:00:00-05:00  161.320007  164.660004  159.809998  161.619995
# 2022-11-09 00:00:00-05:00  161.080002  161.589996  152.500000  152.990005
# 2022-11-10 00:00:00-05:00  158.940002  164.550003  158.389999  164.380005
# 2022-11-11 00:00:00-05:00  165.119995  174.830002  164.949997  173.320007
#
#                             Volume  Dividends  Stock Splits
# Date
# 1973-02-21 00:00:00-05:00   523200        0.0           0.0
# 1973-02-22 00:00:00-05:00   360000        0.0           0.0
# 1973-02-23 00:00:00-05:00   206400        0.0           0.0
# 1973-02-26 00:00:00-05:00   235200        0.0           0.0
# 1973-02-27 00:00:00-05:00   619200        0.0           0.0
# ...                            ...        ...           ...
# 2022-11-07 00:00:00-05:00  2424100        0.0           0.0
# 2022-11-08 00:00:00-05:00  3284600        0.0           0.0
# 2022-11-09 00:00:00-05:00  4018400        0.0           0.0
# 2022-11-10 00:00:00-05:00  4962900        0.0           0.0
# 2022-11-11 00:00:00-05:00  5826900        0.0           0.0
#
# [12544 rows x 7 columns]

# %%
Target_data_df.to_csv("Target.csv")

# %%
Target_data_df.reset_index(inplace=True)
Target_data_df['index'] = Target_data_df.index
Target_data_df['Date'] = pd.to_datetime(Target_data_df['Date'], format='%Y-%m-%d')
Target_data_df = Target_data_df[["Date","Close"]]
Target_data_df
# Out:
#                            Date       Close
# 0     1973-02-21 00:00:00-05:00    0.203631
# 1     1973-02-22 00:00:00-05:00    0.194940
# 2     1973-02-23 00:00:00-05:00    0.192456
# 3     1973-02-26 00:00:00-05:00    0.188731
# 4     1973-02-27 00:00:00-05:00    0.186248
# ...                         ...         ...
# 12539 2022-11-07 00:00:00-05:00  159.869995
# 12540 2022-11-08 00:00:00-05:00  161.619995
# 12541 2022-11-09 00:00:00-05:00  152.990005
# 12542 2022-11-10 00:00:00-05:00  164.380005
# 12543 2022-11-11 00:00:00-05:00  173.320007
#
# [12544 rows x 2 columns]

# %%
Target_pre_covid_df = Target_data_df.loc[((Target_data_df['Date'].dt.year == 2019))]
Target_pre_covid_df.sort_values(by=['Date'])
# Out:
#                            Date       Close
# 11569 2019-01-02 00:00:00-05:00   61.350288
# 11570 2019-01-03 00:00:00-05:00   60.509991
# 11571 2019-01-04 00:00:00-05:00   61.341038
# 11572 2019-01-07 00:00:00-05:00   64.342064
# 11573 2019-01-08 00:00:00-05:00   64.277428
# ...                         ...         ...
# 11816 2019-12-24 00:00:00-05:00  122.483582
# 11817 2019-12-26 00:00:00-05:00  122.807518
# 11818 2019-12-27 00:00:00-05:00  123.112427
# 11819 2019-12-30 00:00:00-05:00  122.807518
# 11820 2019-12-31 00:00:00-05:00  122.159622
#
# [252 rows x 2 columns]

# %%
#Create a dataframe for Target pre-covid stock data (Jan 2019 - Dec 2019) By Month
monthly_close_pre_covid_df = pd.DataFrame(Target_pre_covid_df.groupby(Target_pre_covid_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_pre_covid_df['Store'] = 'Target'
monthly_close_pre_covid_df['Timeframe'] = 'Pre-Covid'

monthly_close_pre_covid_df
# Out:
#     Month       Close   Store  Timeframe
# 0       1   64.355265  Target  Pre-Covid
# 1       2   66.886420  Target  Pre-Covid
# 2       3   72.018149  Target  Pre-Covid
# 3       4   75.263148  Target  Pre-Covid
# 4       5   70.814692  Target  Pre-Covid
# 5       6   81.338563  Target  Pre-Covid
# 6       7   82.330825  Target  Pre-Covid
# 7       8   86.082062  Target  Pre-Covid
# 8       9  101.976588  Target  Pre-Covid
# 9      10  104.089402  Target  Pre-Covid
# 10     11  109.987931  Target  Pre-Covid
# 11     12  121.023505  Target  Pre-Covid

# %%
x = monthly_close_pre_covid_df['Month']
y = monthly_close_pre_covid_df['Close']

plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Target (Pre-Covid) Jan-2019 to Dec-2019");

# %%
# Costco Pre Covid(Jan 2019-Dec 2019)
import yfinance as yf

Costco=yf.Ticker("COST")

print(Costco)

# get stock info
Costco.info

# get historical market data, here max is 5 years.
Costco.history(period="max")
# Out:
# yfinance.Ticker object <COST>
#                                  Open        High         Low       Close  \
# Date
# 1986-07-09 00:00:00-04:00    7.439347    7.700376    7.352337    7.656871
# 1986-07-10 00:00:00-04:00    7.700375    7.743880    7.439345    7.613365
# 1986-07-11 00:00:00-04:00    7.569861    7.613366    7.352336    7.352336
# 1986-07-14 00:00:00-04:00    7.395838    7.395838    7.047799    7.134809
# 1986-07-15 00:00:00-04:00    7.091307    7.091307    6.482237    6.917287
# ...                               ...         ...         ...         ...
# 2022-11-07 00:00:00-05:00  477.049988  490.000000  474.500000  488.549988
# 2022-11-08 00:00:00-05:00  490.730011  498.260010  484.510010  492.760010
# 2022-11-09 00:00:00-05:00  491.899994  497.579987  486.859985  489.970001
# 2022-11-10 00:00:00-05:00  504.950012  514.849976  501.399994  513.130005
# 2022-11-11 00:00:00-05:00  513.130005  516.840027  506.709991  515.469971
#
#                             Volume  Dividends  Stock Splits
# Date
# 1986-07-09 00:00:00-04:00  1116800        0.0           0.0
# 1986-07-10 00:00:00-04:00   595600        0.0           0.0
# 1986-07-11 00:00:00-04:00   800400        0.0           0.0
# 1986-07-14 00:00:00-04:00   738000        0.0           0.0
# 1986-07-15 00:00:00-04:00  2059200        0.0           0.0
# ...                            ...        ...           ...
# 2022-11-07 00:00:00-05:00  2036000        0.0           0.0
# 2022-11-08 00:00:00-05:00  1709900        0.0           0.0
# 2022-11-09 00:00:00-05:00  1640500        0.0           0.0
# 2022-11-10 00:00:00-05:00  3098300        0.0           0.0
# 2022-11-11 00:00:00-05:00  2392400        0.0           0.0
#
# [9163 rows x 7 columns]

# %%
Costco_data_df = pd.DataFrame(Costco.history(period="max"))
Costco_data_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1986-07-09 00:00:00-04:00    7.439347    7.700376    7.352337    7.656871
# 1986-07-10 00:00:00-04:00    7.700374    7.743879    7.439344    7.613364
# 1986-07-11 00:00:00-04:00    7.569863    7.613368    7.352338    7.352338
# 1986-07-14 00:00:00-04:00    7.395842    7.395842    7.047802    7.134812
# 1986-07-15 00:00:00-04:00    7.091306    7.091306    6.482237    6.917286
# ...                               ...         ...         ...         ...
# 2022-11-07 00:00:00-05:00  477.049988  490.000000  474.500000  488.549988
# 2022-11-08 00:00:00-05:00  490.730011  498.260010  484.510010  492.760010
# 2022-11-09 00:00:00-05:00  491.899994  497.579987  486.859985  489.970001
# 2022-11-10 00:00:00-05:00  504.950012  514.849976  501.399994  513.130005
# 2022-11-11 00:00:00-05:00  513.130005  516.840027  506.709991  515.469971
#
#                             Volume  Dividends  Stock Splits
# Date
# 1986-07-09 00:00:00-04:00  1116800        0.0           0.0
# 1986-07-10 00:00:00-04:00   595600        0.0           0.0
# 1986-07-11 00:00:00-04:00   800400        0.0           0.0
# 1986-07-14 00:00:00-04:00   738000        0.0           0.0
# 1986-07-15 00:00:00-04:00  2059200        0.0           0.0
# ...                            ...        ...           ...
# 2022-11-07 00:00:00-05:00  2036000        0.0           0.0
# 2022-11-08 00:00:00-05:00  1709900        0.0           0.0
# 2022-11-09 00:00:00-05:00  1640500        0.0           0.0
# 2022-11-10 00:00:00-05:00  3098300        0.0           0.0
# 2022-11-11 00:00:00-05:00  2392400        0.0           0.0
#
# [9163 rows x 7 columns]

# %%
Costco_data_df.to_csv("Costco.csv")

# %%
Costco_data_df.reset_index(inplace=True)
Costco_data_df['index'] = Costco_data_df.index
Costco_data_df['Date'] = pd.to_datetime(Costco_data_df['Date'], format='%Y-%m-%d')
Costco_data_df = Costco_data_df[["Date","Close"]]
Costco_data_df
# Out:
#                           Date       Close
# 0    1986-07-09 00:00:00-04:00    7.656871
# 1    1986-07-10 00:00:00-04:00    7.613364
# 2    1986-07-11 00:00:00-04:00    7.352338
# 3    1986-07-14 00:00:00-04:00    7.134812
# 4    1986-07-15 00:00:00-04:00    6.917286
# ...                        ...         ...
# 9158 2022-11-07 00:00:00-05:00  488.549988
# 9159 2022-11-08 00:00:00-05:00  492.760010
# 9160 2022-11-09 00:00:00-05:00  489.970001
# 9161 2022-11-10 00:00:00-05:00  513.130005
# 9162 2022-11-11 00:00:00-05:00  515.469971
#
# [9163 rows x 2 columns]

# %%
Costco_pre_covid_df = Costco_data_df.loc[((Costco_data_df['Date'].dt.year == 2019))]
Costco_pre_covid_df.sort_values(by=['Date'])
# Out:
#                           Date       Close
# 8188 2019-01-02 00:00:00-05:00  193.152710
# 8189 2019-01-03 00:00:00-05:00  189.058777
# 8190 2019-01-04 00:00:00-05:00  194.548798
# 8191 2019-01-07 00:00:00-05:00  195.265762
# 8192 2019-01-08 00:00:00-05:00  196.727905
# ...                        ...         ...
# 8435 2019-12-24 00:00:00-05:00  280.277069
# 8436 2019-12-26 00:00:00-05:00  281.705963
# 8437 2019-12-27 00:00:00-05:00  280.162720
# 8438 2019-12-30 00:00:00-05:00  281.143890
# 8439 2019-12-31 00:00:00-05:00  279.981781
#
# [252 rows x 2 columns]

# %%
#Create a dataframe for Costco pre-covid stock data (Jan 2019 - Dec 2019) By Month
monthly_close_pre_covid_df = pd.DataFrame(Costco_pre_covid_df.groupby(Costco_pre_covid_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_pre_covid_df['Store'] = 'Costco'
monthly_close_pre_covid_df['Timeframe'] = 'Pre-Covid'

monthly_close_pre_covid_df
# Out:
#     Month       Close   Store  Timeframe
# 0       1  197.835605  Costco  Pre-Covid
# 1       2  202.170990  Costco  Pre-Covid
# 2       3  219.552737  Costco  Pre-Covid
# 3       4  231.371047  Costco  Pre-Covid
# 4       5  231.871193  Costco  Pre-Covid
# 5       6  245.715375  Costco  Pre-Covid
# 6       7  262.017762  Costco  Pre-Covid
# 7       8  263.056639  Costco  Pre-Covid
# 8       9  277.094041  Costco  Pre-Covid
# 9      10  281.472354  Costco  Pre-Covid
# 10     11  286.810320  Costco  Pre-Covid
# 11     12  280.737456  Costco  Pre-Covid

# %%
# Costco Pre-Covid graph
x = monthly_close_pre_covid_df['Month']
y = monthly_close_pre_covid_df['Close']

plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Costco (Pre-Covid) Jan-2019 to Dec-2019");

# %%
#2. How did the stocks performs during the pandemic 
#   before the vaccine release from Jan-2020 to Nov-2020?

# %%
#Dateframe Before Vaccine(Jan 2020 - Nov 2020)
lowes_before_vaccine_df = lowes_data_df.loc[((lowes_data_df['Date'] >= '2020-01-01') & (lowes_data_df['Date'] < '2020-12-01'))]
lowes_before_vaccine_df.sort_values(by=['Date'])
# Out:
#                            Date       Close
# 10035 2020-01-02 00:00:00-05:00  114.561600
# 10036 2020-01-03 00:00:00-05:00  113.743698
# 10037 2020-01-06 00:00:00-05:00  114.456985
# 10038 2020-01-07 00:00:00-05:00  113.772232
# 10039 2020-01-08 00:00:00-05:00  115.579208
# ...                         ...         ...
# 10261 2020-11-23 00:00:00-05:00  148.734344
# 10262 2020-11-24 00:00:00-05:00  149.982910
# 10263 2020-11-25 00:00:00-05:00  149.905487
# 10264 2020-11-27 00:00:00-05:00  149.702209
# 10265 2020-11-30 00:00:00-05:00  150.815277
#
# [231 rows x 2 columns]

# %%
#Create a dataframe for Lowes before Vaccine stock data (Jan 2020 - Nov 2020) By Month
monthly_close_before_vaccine_df = pd.DataFrame(lowes_before_vaccine_df.groupby(lowes_before_vaccine_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_before_vaccine_df['Store'] = 'Lowes'
monthly_close_before_vaccine_df['Timeframe'] = 'Before Vaccine'

monthly_close_before_vaccine_df
# Out:
#     Month       Close  Store       Timeframe
# 0       1  114.796649  Lowes  Before Vaccine
# 1       2  115.070815  Lowes  Before Vaccine
# 2       3   84.929567  Lowes  Before Vaccine
# 3       4   90.547316  Lowes  Before Vaccine
# 4       5  111.487030  Lowes  Before Vaccine
# 5       6  126.162308  Lowes  Before Vaccine
# 6       7  136.960831  Lowes  Before Vaccine
# 7       8  152.574951  Lowes  Before Vaccine
# 8       9  156.297717  Lowes  Before Vaccine
# 9      10  164.156582  Lowes  Before Vaccine
# 10     11  152.793144  Lowes  Before Vaccine

# %%
x = monthly_close_before_vaccine_df['Month']
y = monthly_close_before_vaccine_df['Close']

plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Lowes (Before Vaccine) Jan-2020 to Nov-2020");

# %%
#Waltmart Dateframe Before Vaccine(Jan 2020 - Nov 2020)
Walmart_before_vaccine_df = Walmart_data_df.loc[((Walmart_data_df['Date'] >= '2020-01-01') & (Walmart_data_df['Date'] < '2020-12-01'))]
Walmart_before_vaccine_df.sort_values(by=['Date'])
# Out:
#                            Date       Close
# 11941 2020-01-02 00:00:00-05:00  113.801071
# 11942 2020-01-03 00:00:00-05:00  112.796432
# 11943 2020-01-06 00:00:00-05:00  112.566795
# 11944 2020-01-07 00:00:00-05:00  111.523895
# 11945 2020-01-08 00:00:00-05:00  111.141182
# ...                         ...         ...
# 12167 2020-11-23 00:00:00-05:00  146.284866
# 12168 2020-11-24 00:00:00-05:00  146.701599
# 12169 2020-11-25 00:00:00-05:00  147.157166
# 12170 2020-11-27 00:00:00-05:00  146.934250
# 12171 2020-11-30 00:00:00-05:00  148.087631
#
# [231 rows x 2 columns]

# %%
#Create a dataframe for Walmart before Vaccine stock data (Jan 2020 - Nov 2020) By Month
monthly_close_before_vaccine_df = pd.DataFrame(Walmart_before_vaccine_df.groupby(Walmart_before_vaccine_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_before_vaccine_df['Store'] = 'Walmart'
monthly_close_before_vaccine_df['Timeframe'] = 'Before Vaccine'

monthly_close_before_vaccine_df
# Out:
#     Month       Close    Store       Timeframe
# 0       1  111.189929  Walmart  Before Vaccine
# 1       2  110.640119  Walmart  Before Vaccine
# 2       3  109.670099  Walmart  Before Vaccine
# 3       4  120.885815  Walmart  Before Vaccine
# 4       5  119.657996  Walmart  Before Vaccine
# 5       6  116.319357  Walmart  Before Vaccine
# 6       7  124.500330  Walmart  Before Vaccine
# 7       8  128.194786  Walmart  Before Vaccine
# 8       9  134.632018  Walmart  Before Vaccine
# 9      10  138.206376  Walmart  Before Vaccine
# 10     11  143.541953  Walmart  Before Vaccine

# %%
x = monthly_close_before_vaccine_df['Month']
y = monthly_close_before_vaccine_df['Close']

plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Walmart (Before Vaccine) Jan-2020 to Nov-2020");

# %%
# Target Dateframe Before Vaccine(Jan 2020 - Nov 2020)
Target_before_vaccine_df = Target_data_df.loc[((Target_data_df['Date'] >= '2020-01-01') & (Target_data_df['Date'] < '2020-12-01'))]
Target_before_vaccine_df.sort_values(by=['Date'])
# Out:
#                            Date       Close
# 11821 2020-01-02 00:00:00-05:00  120.120598
# 11822 2020-01-03 00:00:00-05:00  118.872421
# 11823 2020-01-06 00:00:00-05:00  117.748108
# 11824 2020-01-07 00:00:00-05:00  117.957733
# 11825 2020-01-08 00:00:00-05:00  117.576607
# ...                         ...         ...
# 12047 2020-11-23 00:00:00-05:00  172.601318
# 12048 2020-11-24 00:00:00-05:00  172.892944
# 12049 2020-11-25 00:00:00-05:00  174.798172
# 12050 2020-11-27 00:00:00-05:00  174.749588
# 12051 2020-11-30 00:00:00-05:00  174.516296
#
# [231 rows x 2 columns]

# %%
#Create a dataframe for Target before Vaccine stock data (Jan 2020 - Nov 2020) By Month
monthly_close_before_vaccine_df = pd.DataFrame(Target_before_vaccine_df.groupby(Target_before_vaccine_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_before_vaccine_df['Store'] = 'Target'
monthly_close_before_vaccine_df['Timeframe'] = 'Before Vaccine'

monthly_close_before_vaccine_df
# Out:
#     Month       Close   Store       Timeframe
# 0       1  113.334338  Target  Before Vaccine
# 1       2  109.311141  Target  Before Vaccine
# 2       3   96.364973  Target  Before Vaccine
# 3       4  100.702814  Target  Before Vaccine
# 4       5  112.906796  Target  Before Vaccine
# 5       6  115.248155  Target  Before Vaccine
# 6       7  116.616494  Target  Before Vaccine
# 7       8  136.371380  Target  Before Vaccine
# 8       9  145.346242  Target  Before Vaccine
# 9      10  155.645203  Target  Before Vaccine
# 10     11  160.831613  Target  Before Vaccine

# %%
#Target before vaccine graph
x = monthly_close_before_vaccine_df['Month']
y = monthly_close_before_vaccine_df['Close']

plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Target (Before Vaccine) Jan-2020 to Nov-2020");

# %%
# Costco Dateframe Before Vaccine(Jan 2020 - Nov 2020)
Costco_before_vaccine_df = Costco_data_df.loc[((Costco_data_df['Date'] >= '2020-01-01') & (Costco_data_df['Date'] < '2020-12-01'))]
Costco_before_vaccine_df.sort_values(by=['Date'])
# Out:
#                           Date       Close
# 8440 2020-01-02 00:00:00-05:00  277.667023
# 8441 2020-01-03 00:00:00-05:00  277.895630
# 8442 2020-01-06 00:00:00-05:00  277.971802
# 8443 2020-01-07 00:00:00-05:00  277.533600
# 8444 2020-01-08 00:00:00-05:00  280.715210
# ...                        ...         ...
# 8666 2020-11-23 00:00:00-05:00  366.696533
# 8667 2020-11-24 00:00:00-05:00  369.107819
# 8668 2020-11-25 00:00:00-05:00  372.498993
# 8669 2020-11-27 00:00:00-05:00  373.113892
# 8670 2020-11-30 00:00:00-05:00  376.360870
#
# [231 rows x 2 columns]

# %%
#Create a dataframe for Costco before Vaccine stock data (Jan 2020 - Nov 2020) By Month
monthly_close_before_vaccine_df = pd.DataFrame(Costco_before_vaccine_df.groupby(Costco_before_vaccine_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_before_vaccine_df['Store'] = 'Costco'
monthly_close_before_vaccine_df['Timeframe'] = 'Before Vaccine'

monthly_close_before_vaccine_df
# Out:
#     Month       Close   Store       Timeframe
# 0       1  288.462876  Costco  Before Vaccine
# 1       2  296.615777  Costco  Before Vaccine
# 2       3  284.126581  Costco  Before Vaccine
# 3       4  291.305347  Costco  Before Vaccine
# 4       5  291.620793  Costco  Before Vaccine
# 5       6  289.799638  Costco  Before Vaccine
# 6       7  308.882739  Costco  Before Vaccine
# 7       8  326.779516  Costco  Before Vaccine
# 8       9  330.997910  Costco  Before Vaccine
# 9      10  354.586176  Costco  Before Vaccine
# 10     11  364.330428  Costco  Before Vaccine

# %%
#Costco After Vaccine graph
x = monthly_close_before_vaccine_df['Month']
y = monthly_close_before_vaccine_df['Close']

plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Costco (Before Vaccine) Jan-2020 to Nov-2020");

# %%
#3. How did the stocks perform during the pandemic 
#   after the vaccine release from Dec-2020 to Dec-2021

# %%
# Lowes Dateframe After Vaccine(Dec 2020 - Dec 2021)
lowes_after_vaccine_df = lowes_data_df.loc[((lowes_data_df['Date'] > '2020-11-30') & (lowes_data_df['Date'] <= '2021-12-31'))]
lowes_after_vaccine_df.sort_values(by=['Date'])
# Out:
#                            Date       Close
# 10266 2020-12-01 00:00:00-05:00  148.472992
# 10267 2020-12-02 00:00:00-05:00  146.934052
# 10268 2020-12-03 00:00:00-05:00  147.088928
# 10269 2020-12-04 00:00:00-05:00  145.182205
# 10270 2020-12-07 00:00:00-05:00  147.108307
# ...                         ...         ...
# 10535 2021-12-27 00:00:00-05:00  249.069046
# 10536 2021-12-28 00:00:00-05:00  249.383240
# 10537 2021-12-29 00:00:00-05:00  252.868439
# 10538 2021-12-30 00:00:00-05:00  251.709991
# 10539 2021-12-31 00:00:00-05:00  253.761810
#
# [274 rows x 2 columns]

# %%
#Create a dataframe for Lowes After Vaccine stock data (Dec-2020 to Dec-2021) By Month
monthly_close_after_vaccine_df = pd.DataFrame(lowes_after_vaccine_df.groupby(lowes_after_vaccine_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_after_vaccine_df['Store'] = 'Lowes'
monthly_close_after_vaccine_df['Timeframe'] = 'After Vaccine'

monthly_close_after_vaccine_df
# Out:
#     Month       Close  Store      Timeframe
# 0       1  163.419691  Lowes  After Vaccine
# 1       2  166.780477  Lowes  After Vaccine
# 2       3  169.011627  Lowes  After Vaccine
# 3       4  193.681309  Lowes  After Vaccine
# 4       5  192.620158  Lowes  After Vaccine
# 5       6  185.515793  Lowes  After Vaccine
# 6       7  190.273588  Lowes  After Vaccine
# 7       8  192.649810  Lowes  After Vaccine
# 8       9  201.593034  Lowes  After Vaccine
# 9      10  213.830127  Lowes  After Vaccine
# 10     11  236.664936  Lowes  After Vaccine
# 11     12  201.262564  Lowes  After Vaccine

# %%
# Lowes After Vaccine graph
x = monthly_close_after_vaccine_df['Month']
y = monthly_close_after_vaccine_df['Close']
plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Lowes (After Vaccine) Dec-2020 to Dec-2021");

# %%
# Lowes consolidate pre-covid, before vaccine and after vaccine graph
frames = [monthly_close_pre_covid_df, monthly_close_before_vaccine_df, monthly_close_after_vaccine_df]

lowes_FINAL_df = pd.concat(frames)

fig,ax = plt.subplots()

for timeframe in ['Pre-Covid', 'Before Vaccine', 'After Vaccine']:
    ax.plot(lowes_FINAL_df[lowes_FINAL_df.Timeframe==timeframe].Month,lowes_FINAL_df[lowes_FINAL_df.Timeframe==timeframe].Close,label=timeframe)

plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Lowes ()")
ax.legend(loc='best');

# %%
# Walmart Dateframe After Vaccine(Dec 2020 - Dec 2021)
Walmart_after_vaccine_df = Walmart_data_df.loc[((Walmart_data_df['Date'] > '2020-11-30') & (Walmart_data_df['Date'] <= '2021-12-31'))]
Walmart_after_vaccine_df.sort_values(by=['Date'])
# Out:
#                            Date       Close
# 12172 2020-12-01 00:00:00-05:00  147.942230
# 12173 2020-12-02 00:00:00-05:00  145.887482
# 12174 2020-12-03 00:00:00-05:00  144.705017
# 12175 2020-12-04 00:00:00-05:00  144.327042
# 12176 2020-12-07 00:00:00-05:00  143.551636
# ...                         ...         ...
# 12441 2021-12-27 00:00:00-05:00  139.104019
# 12442 2021-12-28 00:00:00-05:00  141.100250
# 12443 2021-12-29 00:00:00-05:00  141.031082
# 12444 2021-12-30 00:00:00-05:00  141.485672
# 12445 2021-12-31 00:00:00-05:00  142.987778
#
# [274 rows x 2 columns]

# %%
#Create a dataframe for Walmart After Vaccine stock data (JDec-2020 to Dec-2021) By Month
monthly_close_after_vaccine_df = pd.DataFrame(Walmart_after_vaccine_df.groupby(Walmart_after_vaccine_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_after_vaccine_df['Store'] = 'Walmart'
monthly_close_after_vaccine_df['Timeframe'] = 'After Vaccine'

monthly_close_after_vaccine_df
# Out:
#     Month       Close    Store      Timeframe
# 0       1  141.788834  Walmart  After Vaccine
# 1       2  136.633175  Walmart  After Vaccine
# 2       3  128.750175  Walmart  After Vaccine
# 3       4  136.229757  Walmart  After Vaccine
# 4       5  137.978574  Walmart  After Vaccine
# 5       6  136.345677  Walmart  After Vaccine
# 6       7  138.435152  Walmart  After Vaccine
# 7       8  145.327045  Walmart  After Vaccine
# 8       9  142.169243  Walmart  After Vaccine
# 9      10  140.392388  Walmart  After Vaccine
# 10     11  144.257770  Walmart  After Vaccine
# 11     12  140.600971  Walmart  After Vaccine

# %%
# Marwart after vaccine graph
x = monthly_close_after_vaccine_df['Month']
y = monthly_close_after_vaccine_df['Close']
plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Walmart (After Vaccine) Dec-2020 to Dec-2021");

# %%
#Walmart consolidate pre-covid, before vaccine and after vaccine graph
frames = [monthly_close_pre_covid_df, monthly_close_before_vaccine_df, monthly_close_after_vaccine_df]

Walmart_FINAL_df = pd.concat(frames)

fig,ax = plt.subplots()

for timeframe in ['Pre-Covid', 'Before Vaccine', 'After Vaccine']:
    ax.plot(Walmart_FINAL_df[Walmart_FINAL_df.Timeframe==timeframe].Month,Walmart_FINAL_df[Walmart_FINAL_df.Timeframe==timeframe].Close,label=timeframe)

plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Walmart")
ax.legend(loc='best');

# %%
# Target Dateframe After Vaccine(Dec-2020 to Dec-2021)
Target_after_vaccine_df = Target_data_df.loc[((Target_data_df['Date'] > '2020-11-30') & (Target_data_df['Date'] <= '2021-12-31'))]
Target_after_vaccine_df.sort_values(by=['Date'])
# Out:
#                            Date       Close
# 12052 2020-12-01 00:00:00-05:00  174.049713
# 12053 2020-12-02 00:00:00-05:00  171.483429
# 12054 2020-12-03 00:00:00-05:00  170.035049
# 12055 2020-12-04 00:00:00-05:00  170.141983
# 12056 2020-12-07 00:00:00-05:00  168.081192
# ...                         ...         ...
# 12321 2021-12-27 00:00:00-05:00  220.832916
# 12322 2021-12-28 00:00:00-05:00  221.631119
# 12323 2021-12-29 00:00:00-05:00  224.597214
# 12324 2021-12-30 00:00:00-05:00  228.529068
# 12325 2021-12-31 00:00:00-05:00  228.065903
#
# [274 rows x 2 columns]

# %%
#Create a dataframe for Target After Vaccine stock data (Dec-2020 to Dec-2021) By Month
monthly_close_after_vaccine_df = pd.DataFrame(Target_after_vaccine_df.groupby(Target_after_vaccine_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_after_vaccine_df['Store'] = 'Target'
monthly_close_after_vaccine_df['Timeframe'] = 'After Vaccine'

monthly_close_after_vaccine_df
# Out:
#     Month       Close   Store      Timeframe
# 0       1  183.985310  Target  After Vaccine
# 1       2  183.959926  Target  After Vaccine
# 2       3  179.468118  Target  After Vaccine
# 3       4  200.505209  Target  After Vaccine
# 4       5  211.202663  Target  After Vaccine
# 5       6  229.145639  Target  After Vaccine
# 6       7  247.994178  Target  After Vaccine
# 7       8  250.762922  Target  After Vaccine
# 8       9  237.770829  Target  After Vaccine
# 9      10  239.072299  Target  After Vaccine
# 10     11  250.182667  Target  After Vaccine
# 11     12  198.856723  Target  After Vaccine

# %%
#Target (After Vaccine graph)
x = monthly_close_after_vaccine_df['Month']
y = monthly_close_after_vaccine_df['Close']
plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Target (After Vaccine) Dec-2020 to Dec-2021");

# %%
# Target consolidate pre-covid, before vaccine and after vaccine graph
frames = [monthly_close_pre_covid_df, monthly_close_before_vaccine_df, monthly_close_after_vaccine_df]

Target_FINAL_df = pd.concat(frames)

fig,ax = plt.subplots()

for timeframe in ['Pre-Covid', 'Before Vaccine', 'After Vaccine']:
    ax.plot(Target_FINAL_df[Target_FINAL_df.Timeframe==timeframe].Month,Target_FINAL_df[Target_FINAL_df.Timeframe==timeframe].Close,label=timeframe)

plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Target")
ax.legend(loc='best');

# %%
# Costco Dateframe After Vaccine(Dec 2020 - Dec 2021)
Costco_after_vaccine_df = Costco_data_df.loc[((Costco_data_df['Date'] > '2020-11-30') & (Costco_data_df['Date'] <= '2021-12-31'))]
Costco_after_vaccine_df.sort_values(by=['Date'])
# Out:
#                           Date       Close
# 8671 2020-12-01 00:00:00-05:00  382.068787
# 8672 2020-12-02 00:00:00-05:00  378.066345
# 8673 2020-12-03 00:00:00-05:00  368.750214
# 8674 2020-12-04 00:00:00-05:00  368.139038
# 8675 2020-12-07 00:00:00-05:00  368.040405
# ...                        ...         ...
# 8940 2021-12-27 00:00:00-05:00  559.725098
# 8941 2021-12-28 00:00:00-05:00  560.887390
# 8942 2021-12-29 00:00:00-05:00  563.996521
# 8943 2021-12-30 00:00:00-05:00  560.162170
# 8944 2021-12-31 00:00:00-05:00  563.927002
#
# [274 rows x 2 columns]

# %%
#Create a dataframe for Costco After Vaccine stock data (Dec-2020 to Dec-2021) By Month
monthly_close_after_vaccine_df = pd.DataFrame(Costco_after_vaccine_df.groupby(Costco_after_vaccine_df.Date.dt.month)['Close'].mean())\
                        .reset_index()\
                        .rename(columns={'Date': 'Month'})

#Add Store and timeframe column

monthly_close_after_vaccine_df['Store'] = 'Costco'
monthly_close_after_vaccine_df['Timeframe'] = 'After Vaccine'

monthly_close_after_vaccine_df
# Out:
#     Month       Close   Store      Timeframe
# 0       1  358.897106  Costco  After Vaccine
# 1       2  346.886226  Costco  After Vaccine
# 2       3  328.233462  Costco  After Vaccine
# 3       4  362.528014  Costco  After Vaccine
# 4       5  377.196577  Costco  After Vaccine
# 5       6  382.294744  Costco  After Vaccine
# 6       7  408.985135  Costco  After Vaccine
# 7       8  443.425150  Costco  After Vaccine
# 8       9  454.467768  Costco  After Vaccine
# 9      10  459.987972  Costco  After Vaccine
# 10     11  519.306488  Costco  After Vaccine
# 11     12  455.896036  Costco  After Vaccine

# %%
# Costco after vaccine graph
x = monthly_close_after_vaccine_df['Month']
y = monthly_close_after_vaccine_df['Close']
plt.plot(x, y)
plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Costco (After Vaccine) Dec-2020 to Dec-2021");

# %%
frames = [monthly_close_pre_covid_df, monthly_close_before_vaccine_df, monthly_close_after_vaccine_df]

Costco_FINAL_df = pd.concat(frames)

fig,ax = plt.subplots()

for timeframe in ['Pre-Covid', 'Before Vaccine', 'After Vaccine']:
    ax.plot(Costco_FINAL_df[Costco_FINAL_df.Timeframe==timeframe].Month,Costco_FINAL_df[Costco_FINAL_df.Timeframe==timeframe].Close,label=timeframe)

plt.xlim(0,12,1)
plt.xticks(np.arange(min(x), max(x)+1, 1))
plt.xlabel("Month")
plt.ylabel("Close($)")
plt.title("Costco")
ax.legend(loc='best');
